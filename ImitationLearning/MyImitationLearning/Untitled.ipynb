# %%
import pandas as pd

# %%
df = pd.read_csv('./raw_data/2023-02-09-19-45-37/airsim_rec.txt', sep='\t')

# %%
print(df.shape)
print(df)
# Out:
# (4387, 17)
#      VehicleName      TimeStamp    POS_X    POS_Y     POS_Z       Q_W  \
# 0       PhysXCar  1675939537158  691.591 -311.197 -0.639756  0.304296
# 1       PhysXCar  1675939537278  690.488 -310.414 -0.639333  0.303769
# 2       PhysXCar  1675939537407  688.481 -308.995 -0.638559  0.302526
# 3       PhysXCar  1675939537552  687.612 -308.382 -0.638200  0.302467
# 4       PhysXCar  1675939537671  686.262 -307.428 -0.638027  0.302440
# ...          ...            ...      ...      ...       ...       ...
# 4382    PhysXCar  1675939846095  463.583 -234.602  7.459550  0.713059
# 4383    PhysXCar  1675939846142  463.586 -234.442  7.462850  0.713064
# 4384    PhysXCar  1675939846190  463.589 -234.288  7.465370  0.713071
# 4385    PhysXCar  1675939846237  463.592 -234.136  7.467650  0.713076
# 4386    PhysXCar  1675939846296  463.595 -233.955  7.470610  0.713075
#
#            Q_X       Q_Y       Q_Z  Throttle  Steering  Brake  Gear  \
# ...

# %%
df.head()
# Out:
#   VehicleName      TimeStamp    POS_X    POS_Y     POS_Z       Q_W       Q_X  \
# 0    PhysXCar  1675939537158  691.591 -311.197 -0.639756  0.304296 -0.001941
# 1    PhysXCar  1675939537278  690.488 -310.414 -0.639333  0.303769 -0.001863
# 2    PhysXCar  1675939537407  688.481 -308.995 -0.638559  0.302526 -0.001441
# 3    PhysXCar  1675939537552  687.612 -308.382 -0.638200  0.302467 -0.000989
# 4    PhysXCar  1675939537671  686.262 -307.428 -0.638027  0.302440 -0.001347
#
#         Q_Y       Q_Z  Throttle  Steering  Brake  Gear  Handbrake      RPM  \
# 0  0.000306  0.952575         1         0      0     2          0  4791.86
# 1  0.000469  0.952744         1         0      0     2          0  4864.46
# 2  0.000447  0.953140         1         0      0     0          0  4767.18
# 3  0.000341  0.953159         1         0      0     3          0  4329.94
# 4  0.000505  0.953167         1         1      0     3          0  4247.49
#
#      Speed                                ImageFile
# ...

# %%
df
# Out:
#      VehicleName      TimeStamp    POS_X    POS_Y     POS_Z       Q_W  \
# 0       PhysXCar  1675939537158  691.591 -311.197 -0.639756  0.304296
# 1       PhysXCar  1675939537278  690.488 -310.414 -0.639333  0.303769
# 2       PhysXCar  1675939537407  688.481 -308.995 -0.638559  0.302526
# 3       PhysXCar  1675939537552  687.612 -308.382 -0.638200  0.302467
# 4       PhysXCar  1675939537671  686.262 -307.428 -0.638027  0.302440
# ...          ...            ...      ...      ...       ...       ...
# 4382    PhysXCar  1675939846095  463.583 -234.602  7.459550  0.713059
# 4383    PhysXCar  1675939846142  463.586 -234.442  7.462850  0.713064
# 4384    PhysXCar  1675939846190  463.589 -234.288  7.465370  0.713071
# 4385    PhysXCar  1675939846237  463.592 -234.136  7.467650  0.713076
# 4386    PhysXCar  1675939846296  463.595 -233.955  7.470610  0.713075
#
#            Q_X       Q_Y       Q_Z  Throttle  Steering  Brake  Gear  \
# ...

# %%
df.columns
# Out:
# Index(['VehicleName', 'TimeStamp', 'POS_X', 'POS_Y', 'POS_Z', 'Q_W', 'Q_X',
#        'Q_Y', 'Q_Z', 'Throttle', 'Steering', 'Brake', 'Gear', 'Handbrake',
#        'RPM', 'Speed', 'ImageFile'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4387 entries, 0 to 4386
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   VehicleName  4387 non-null   object
#  1   TimeStamp    4387 non-null   int64
#  2   POS_X        4387 non-null   float64
#  3   POS_Y        4387 non-null   float64
#  4   POS_Z        4387 non-null   float64
#  5   Q_W          4387 non-null   float64
#  6   Q_X          4387 non-null   float64
#  7   Q_Y          4387 non-null   float64
#  8   Q_Z          4387 non-null   float64
#  9   Throttle     4387 non-null   int64
#  10  Steering     4387 non-null   int64
#  11  Brake        4387 non-null   int64
#  12  Gear         4387 non-null   int64
#  13  Handbrake    4387 non-null   int64
#  14  RPM          4387 non-null   float64
#  15  Speed        4387 non-null   float64
#  16  ImageFile    4387 non-null   object
# dtypes: float64(9), int64(6), object(2)
# memory usage: 582.8+ KB

# %%
df.describe()
# Out:
#           TimeStamp        POS_X        POS_Y        POS_Z          Q_W  \
# count  4.387000e+03  4387.000000  4387.000000  4387.000000  4387.000000
# mean   1.675940e+12   439.770370  -197.599569     1.465595     0.628849
# std    8.692617e+04   275.921913   134.315084     3.494101     0.344407
# min    1.675940e+12   -17.801400  -408.928000    -1.028900     0.000760
# 25%    1.675940e+12   173.954000  -304.052000    -0.721341     0.266996
# 50%    1.675940e+12   463.940000  -192.908000    -0.647257     0.745824
# 75%    1.675940e+12   681.038000   -86.485500     4.476445     0.966420
# max    1.675940e+12   895.334000     0.872707     8.140410     0.999976
#
#                Q_X          Q_Y          Q_Z     Throttle     Steering  \
# count  4387.000000  4387.000000  4387.000000  4387.000000  4387.000000
# mean      0.003807     0.000057     0.128569     0.740141    -0.036471
# std       0.017962     0.018012     0.684744     0.438607     0.646320
# ...
